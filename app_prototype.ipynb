# %% [markdown]
# <a href="https://colab.research.google.com/github/StudentHubCoder/community-opportunity-hub/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# The exact website address with "quotes." included!
url = "https://quotes.toscrape.com/"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Look for the quote block
element = soup.find('span', class_='text')

if element:
    print("🎉 SUCCESS! The first quote found on the page is:")
    print(element.text)
else:
    print("Could not find the quote. Double check the URL styling!")
# Out:
# 🎉 SUCCESS! The first quote found on the page is:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”

# %%
import requests
from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com/"

# This header tricks the website into thinking we are a normal Chrome browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# We pass the headers inside our request
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

all_quotes = soup.find_all('span', class_='text')

print(f"📊 Status Code: {response.status_code}")
print(f"📊 Found {len(all_quotes)} quotes on this page!\n")

for index, quote in enumerate(all_quotes, start=1):
    print(f"Quote #{index}: {quote.text}")
    print("-" * 40)
# Out:
# 📊 Status Code: 200
# 📊 Found 10 quotes on this page!
#
# Quote #1: “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# ----------------------------------------
# Quote #2: “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# ----------------------------------------
# Quote #3: “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# ----------------------------------------
# Quote #4: “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# ----------------------------------------
# Quote #5: “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# ----------------------------------------
# Quote #6: “Try not to become a man of success. Rather become a man of value.”
# ...
